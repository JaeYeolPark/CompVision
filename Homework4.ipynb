# %% [markdown]
# # 투시 변환

# %% [markdown]
# ## dsu4.jpg

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu4.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[235,457],[238,269],[569,221],[564,493]])
pts2 = np.float32([[235,457],[235,270],[570,270],[570,457]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
cv2.imshow('image',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## dsu5.jpg

# %%
img = cv2.imread('dsu5.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[585,547],[577,338],[753,374],[763,542]])
pts2 = np.float32([[585,547],[585,340],[800,340],[800,547]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
cv2.imshow('image',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## report.png

# %%
img = cv2.imread('report.png')
rows,cols,ch = img.shape
pts1 = np.float32([[215,1548],[282,486],[1038,493],[1010,1596]])
pts2 = np.float32([[215,1548],[215,490],[1040,490],[1040,1548]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
